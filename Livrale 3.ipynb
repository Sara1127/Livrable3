# %%
#Importations des modules

import numpy as np
from math import e
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from scipy.optimize import fsolve
import sympy as sp
from scipy import signal
from scipy.signal import ss2tf

# %%
# DÉFINISSION DES PARAMÈTRES

# Antoine (valide de 60 à 150 °C)
Ka = 7.9668
Kb = 11668.21
Kc = 228

# Chaleur latente de vaporisation (valide de 60 à 150 °C)
a = 2489
b = -1.95
c = -0.0037

# %% [markdown]
# ÉQUATION NON LINÉARISER

# %%
#DÉFINITION DES FONCTIONS

# Fonction : Calcul la tension de vapeur d'un composé

def tension_vapeur_Pa(Ka,Kb,Kc,T):
    # ------- Entrées --------
    # ka,kb,kc : coefficients de la molécule
    # T : Température de la molécule , en (°C)
    
    # ------- Sortie -------
    # Retourne la tension de vapeur de la molécule en Pa
    
    Tension_vapeur = 10**(ka-(kb/(kc+T)))

    return Tension_vapeur*101325/760

#Fonction : Calcul de la chaleur latente de vaporisation

def 





# Valeurs des variables connues
Msuc = 342,3 #g/mol
Mns = 98 #g/mol
Meau = 18.015 #g/mol
Xsuc = 85.71/657.91 
Xns = 7.48 /657.91 
Cpsuc = 1.23 #KJ/(kg*K)
Cpns = 0.816 #KJ/(kg*K)
Fin = 657.91 #tonne/h
Fliqout = 454.77 #tonne/h
Xhi = 203.15 #tonne/h
A = 

rho = 1000 - 0.1211*Tev - 0.003012*Tev**2 + 3.876 *Xsol + 0.01751*Xsol**2
Cpsol = (Xsuc/(Xsuc+Xns))*Cpsuc +(Xns/(Xsuc+Xns))*Cpns
Msol = (Xsuc/Xsol)/Msuc + (Xns/Xsol)/Mns  
Xeau = ((1-Xsol)/Meau)/((1-Xsol)/Meau)+ Xsol/Msol
Xhi = A*kp*(Ppar-Pvap)
Ppar = Psat*Xeau    
Fliqout = kf*sqrt(h)
Qev = U*A*(Tc1-Tev)

#Paramètres pour l'enthalpie de l'évaporation
a = 2489
b = -1.95
c= - 0.0037
Heva = a + b*Tev + c*Tev**2 

#Paramètres pour la loi d'Antoine 
kb = 1668.21
ka = 7.96681
kc = 228
Psat = math.exp(ka - kb / (kc + T))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 11
#       9 Fliqout = 454.77 #tonne/h
#      10 Xhi = 203.15 #tonne/h
# ---> 11 rho = 1000 - 0.1211*Tev - 0.003012*Tev**2 + 3.876 *Xsol + 0.01751*Xsol**2
#      12 A = 100
#      14 Cpsol = (Xsuc/(Xsuc+Xns))*Cpsuc +(Xns/(Xsuc+Xns))*Cpns
#
# NameError: name 'Tev' is not defined

# %%
#Définition des équations différentielles

# %%
def bilans(x, p, u):
    #Variables d'état
    [h, Xsol, Tev, rho] = x
    #Paramètres
    [Msol, rhof, UmAm, Cpf, Cpm] = p
    #Variables indépendantes
    [F, Tb, Text] = u

    #Système d'équations différetielles
    drhodt = 
    dhdt = ((1/(A*rho))*(Fin - Fliqout - Xhi)) - drhodt*h/rho
    dTevdt = ()
    dXsoldt = ()
    
    return [dhdt]
